# %%
import glob

DRONE_MODEL_PATHS = sorted(glob.glob("/home/seobin1027/tasks2/연구과제/드론로봇/upgrade-ver/models/drone/*"))

# %%
DRONE_MODEL_PATHS
# Out:
# ['/home/seobin1027/tasks2/연구과제/드론로봇/upgrade-ver/models/drone/drone_person_vehicle_best_yolo11m(0.947).pt',
#  '/home/seobin1027/tasks2/연구과제/드론로봇/upgrade-ver/models/drone/drone_yolo26m_100e_640img.pt',
#  '/home/seobin1027/tasks2/연구과제/드론로봇/upgrade-ver/models/drone/drone_yolo26m_100e_640img_10fz.pt',
#  '/home/seobin1027/tasks2/연구과제/드론로봇/upgrade-ver/models/drone/drone_yolo26m_100e_640img_10fz_unfz.pt']
